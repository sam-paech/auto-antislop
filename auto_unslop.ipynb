# %%
# %%
##################################
# Imports                        #
##################################
import json, subprocess, sys, math, re, itertools, collections, os, pathlib, datetime
from pathlib import Path
from collections import Counter, defaultdict
import pandas as pd
import nltk
import numpy as np

from slop_forensics.slop_lists import extract_and_save_slop_phrases as _extract_slop_phrases
from slop_forensics import config as _sf_cfg
from slop_forensics.analysis import (
    get_word_counts, filter_mostly_numeric, merge_plural_possessive_s,
    filter_stopwords, filter_common_words, analyze_word_rarity,
    find_over_represented_words
)
from wordfreq import word_frequency   # used inside the toolkit too


# %%
##################################
# Pipeline Parameters            #
##################################
RUN_PIPELINE        = True  # ⇠ set False to skip the full pipeline (e.g., if you only want to inspect results)
NUM_ITERATIONS      = 3     # Number of iterations to run

ENABLE_NGRAM_BAN    = True
TOP_N_INITIAL_BAN   = 300   # N-grams to ban from each of 4 lists in the first iteration
TOP_N_SUBSEQUENT_BAN= 100   # N-grams to ban from each of 4 lists in subsequent iterations
TOP_N_REPETITION_STAT = 50 # N-grams from each of 4 lists to track for repetition stats

# Parameters for main.py (generation)
THREADS             = 80    # Adjust based on your system
MAX_PROMPTS         = 2000  # Max prompts for generation, can be reduced for faster iterations
HF_DATASET_NAME     = 'Nitral-AI/Reddit-SFW-Writing_Prompts_ShareGPT'
HF_DATASET_SPLIT    = 'train'
LOGGING_LEVEL       = 'INFO'

# Parameters for N-gram analysis (within each iteration)
HUMAN_PROFILE_PATH  = Path('data/human_writing_profile.json')
TOP_K_WORDS         = 200_000
TOP_K_BIGRAMS       = 1_000
TOP_K_TRIGRAMS      = 1_000
MIN_WORD_LEN        = 4
FREQ_NORM_DENOM     = 100_000

# Params for slop phrase banning
COMPUTE_OVERREP_WORDS             = True    # create CSV each iter
ENABLE_SLOP_PHRASE_BAN            = True    # maintain banned-phrase JSON
BAN_OVERREP_WORDS_IN_PHRASE_LIST  = True    # ⬅ NEW: also add words to that list
DICT_OVERREP_INITIAL      = 400   # dictionary words (wf > 0) first iter
DICT_OVERREP_SUBSEQUENT   = 200   # dictionary words later iters
NODICT_OVERREP_INITIAL    =  80   # non-dictionary words (wf == 0) first iter
NODICT_OVERREP_SUBSEQUENT =  20   # non-dictionary words later iters
MIN_PHRASE_FREQ_TO_KEEP           = 2       # ⬅ NEW: only keep phrases seen > 1×


# how many slop phrases to (newly) ban each round
TOP_N_INITIAL_SLOP_BAN   = 200
TOP_N_SUBSEQUENT_SLOP_BAN    = 100

# where we’ll keep the growing list
BANNED_SLOP_PHRASES_FILE = "banned_slop_phrases.json"

# Output directory for the experiment
# (A timestamped subdirectory will be created under this)
EXPERIMENT_BASE_DIR = Path("results") / "iterative_antislop_experiment"


# Ensure nltk resources are available
def download_nltk_resource(resource_id, resource_name):
    try:
        nltk.data.find(resource_id)
        print(f"NLTK '{resource_name}' resource found.")
    except LookupError:
        print(f"NLTK '{resource_name}' resource not found. Downloading...")
        nltk.download(resource_name, quiet=True)
        print(f"NLTK '{resource_name}' resource downloaded.")
    except Exception as e:
        print(f"Warning: Could not automatically verify/download NLTK '{resource_name}' resource: {e}.")


download_nltk_resource('tokenizers/punkt', 'punkt')
download_nltk_resource('tokenizers/punkt_tab', 'punkt_tab')
download_nltk_resource('corpora/stopwords', 'stopwords')

from nltk import ngrams
from nltk.corpus import stopwords

# Attempt to import from slop_forensics. If not found, provide stubs.
# In a real environment, ensure slop_forensics is in PYTHONPATH or installed.
try:
    from slop_forensics.utils import load_jsonl_file, normalize_text, extract_words
    print("Successfully imported from slop_forensics.utils")
except ImportError:
    print("Warning: slop_forensics.utils not found. Using placeholder functions.")
    print("Please ensure slop_forensics is installed or in your PYTHONPATH for full functionality.")
    
    def load_jsonl_file(file_path_str: str):
        data = []
        with open(file_path_str, 'r', encoding='utf-8') as f:
            for line in f:
                data.append(json.loads(line))
        return data

    def normalize_text(text: str) -> str:
        text = text.lower()
        text = re.sub(r"<[^>]+>", " ", text)  # Remove HTML tags
        text = re.sub(r"[\W_]+", " ", text)    # Replace non-alphanumeric with space
        text = re.sub(r"\s+", " ", text).strip() # Normalize whitespace
        return text

    def extract_words(normalized_text: str, min_len: int):
        # This is a simplified version. The original might have more sophisticated logic.
        return [word for word in normalized_text.split() if len(word) >= min_len or "'" in word]

# Initialize STOP_WORDS
try:
    STOP_WORDS = set(stopwords.words('english'))
    print(f"Loaded {len(STOP_WORDS)} NLTK stopwords for 'english'.")
except LookupError:
    print(f"NLTK 'stopwords' not found even after download attempt. Stopword filtering will be limited.")
    STOP_WORDS = set()


# %%
##################################
# Helper Functions               #
##################################

###############################################################################
# RUN GENERATION SCRIPT — RESTORED N-GRAM BANNING #############################
###############################################################################
def run_generation_script(
    iter_idx: int,
    output_jsonl_path: Path,
    banned_ngrams_file_path: Path | None = None,
    *,
    slop_phrases_file_path: Path | None = None,
    top_n_slop_phrases: int | None = None,
) -> None:
    """
    Invoke main.py for a single iteration of the pipeline.

    Parameters
    ----------
    iter_idx : int
        0-based iteration counter – only used for console logs.
    output_jsonl_path : Path
        Destination of generated text from main.py.
    banned_ngrams_file_path : Path | None
        JSON list of N-grams to ban (classic anti-slop mechanism).
    slop_phrases_file_path : Path | None, keyword-only
        JSON list of slop phrases produced by Slop-Forensics.
    top_n_slop_phrases : int | None, keyword-only
        Value for main.py’s --top-n-slop-phrases flag.

    Raises
    ------
    subprocess.CalledProcessError
        If main.py returns a non-zero exit status.
    """

    # ---------------------------------------------------------------- build CLI
    cmd: list[str] = [
        sys.executable, "main.py",
        "--output-jsonl",     str(output_jsonl_path),
        "--input-hf-dataset", HF_DATASET_NAME,
        "--hf-dataset-split", HF_DATASET_SPLIT,
        "--threads",          str(THREADS),
        "--max-prompts",      str(MAX_PROMPTS),
        "--logging-level",    LOGGING_LEVEL,
    ]

    # ------ ALWAYS pass the N-gram ban list if supplied -----------------------
    if banned_ngrams_file_path is not None:
        # Warn if the caller handed us a path that doesn’t exist **yet**,
        # but still forward it – main.py can decide what to do.
        if not banned_ngrams_file_path.exists():
            print(f"⚠️  Warning: banned-N-gram file does not exist at call time: "
                  f"{banned_ngrams_file_path}")
        cmd += ["--ngram-banned-file", str(banned_ngrams_file_path)]

    # ------ Optional Slop-Forensics phrase banning ----------------------------
    if slop_phrases_file_path is not None:
        if not slop_phrases_file_path.exists():
            print(f"⚠️  Warning: slop-phrase file not found: "
                  f"{slop_phrases_file_path}")
        cmd += ["--slop-phrases-file", str(slop_phrases_file_path)]

    if top_n_slop_phrases is not None and top_n_slop_phrases > 0:
        cmd += ["--top-n-slop-phrases", str(top_n_slop_phrases)]

    # ------------------------------------------------------------------ logging
    print(f"\n┏━━ Iteration {iter_idx}: launching main.py ━━━━━━━━━━━━━━━━━━━━━━┓")
    print(" ".join(cmd))
    print("┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛\n")

    # ----------------------------------------------------------------- execute
    try:
        subprocess.run(cmd, check=True)
        print(f"✅  main.py finished — output saved to {output_jsonl_path}")
    except subprocess.CalledProcessError as exc:
        print(f"❌  main.py exited with status {exc.returncode}")
        raise





BOOST_EXPONENT     = 0.75   # boost  by corpus_frequency^BOOST_EXPONENT
ATTEN_EXPONENT     = 0.75   # attenuate by wordfreq_frequency^ATTEN_EXPONENT

def build_overrep_word_csv(texts: list[str],
                           out_csv: Path,
                           top_n: int = TOP_K_WORDS):
    """
    Returns three objects:
        1. pandas.DataFrame with columns:
           ['word','ratio_corpus/wordfreq','corpus_freq','wordfreq_freq',
            'modulated_score' (only for dictionary words)]
        2. list[str]  – dictionary words   (wordfreq_freq > 0), sorted by
           modulated_score (highest first)
        3. list[str]  – non-dictionary words (wordfreq_freq == 0), order unchanged
    The CSV written to *out_csv* contains the full DataFrame.
    """
    # ---------- flatten + count with official toolkit helpers ---------------
    counts      = get_word_counts(texts)
    counts      = filter_mostly_numeric(counts)
    counts      = merge_plural_possessive_s(counts)
    counts      = filter_stopwords(counts)

    corpus_freqs, wf_freqs, *_ = analyze_word_rarity(counts)
    overrep = find_over_represented_words(corpus_freqs, wf_freqs, top_n=top_n)

    # ---------- DataFrame ----------------------------------------------------
    df = pd.DataFrame(
        overrep,
        columns=["word",
                 "ratio_corpus/wordfreq",
                 "corpus_freq",
                 "wordfreq_freq"]
    )

    # ensure numeric dtypes
    num_cols = ["ratio_corpus/wordfreq", "corpus_freq", "wordfreq_freq"]
    df[num_cols] = df[num_cols].apply(pd.to_numeric, errors="coerce")

    # ---------- modulated_score for dictionary words -------------------------
    dict_mask = df["wordfreq_freq"] > 0
    if dict_mask.any():
        boost  = np.power(df.loc[dict_mask, "corpus_freq"], BOOST_EXPONENT)
        atten  = np.power(df.loc[dict_mask, "wordfreq_freq"], ATTEN_EXPONENT)
        df.loc[dict_mask, "modulated_score"] = (
            df.loc[dict_mask, "ratio_corpus/wordfreq"] * boost / atten
        )

    # ---------- write CSV ----------------------------------------------------
    df.to_csv(out_csv, index=False)
    print(f"🔎  over-rep word CSV → {out_csv}  ({len(df)} rows)")

    # ---------- split & sort -------------------------------------------------
    dict_words   = (
        df[dict_mask]
        .sort_values("modulated_score", ascending=False)
        ["word"]
        .tolist()
    )
    nodict_words = df[~dict_mask]["word"].tolist()

    return df, dict_words, nodict_words

def select_overrep_words_for_ban(dict_words: list[str],
                                 nodict_words: list[str],
                                 is_first_iteration: bool) -> list[str]:
    """Return the combined subset according to per-iteration quotas."""
    if is_first_iteration:
        dict_quota   = DICT_OVERREP_INITIAL
        nodict_quota = NODICT_OVERREP_INITIAL
    else:
        dict_quota   = DICT_OVERREP_SUBSEQUENT
        nodict_quota = NODICT_OVERREP_SUBSEQUENT

    return dict_words[:dict_quota] + nodict_words[:nodict_quota]


from slop_forensics.slop_lists import extract_and_save_slop_phrases as _extract_slop_phrases

def update_banned_slop_phrases(json_path: Path,
                               texts: list[str],
                               how_many_new: int,
                               tmp_dir: Path,
                               over_represented_words: list[str] | None = None) -> None:
    """
    1.  Runs Slop-Forensics phrase extractor (`extract_and_save_slop_phrases`)
        on `texts`, writing *slop_list_phrases.jsonl* into `tmp_dir`.
    2.  Reads that file; keeps phrases whose frequency ≥ MIN_PHRASE_FREQ_TO_KEEP.
        Takes the first `how_many_new` unseen phrases (most-frequent first).
    3.  Optionally appends `extra_tokens` (e.g. over-rep words) as one-word
        phrases, limited by TOP_N_OVERREP_WORDS_TO_BAN.
    4.  Merges with any existing ban list and writes the file back in the
        required  **[["phrase", 1], …]** format (sorted alphabetically).
    """

    # --------------------------------------------------------------------- #
    # 1.  Run the heavy Slop-Forensics extractor (this can take time!)      #
    # --------------------------------------------------------------------- #
    tmp_dir.mkdir(parents=True, exist_ok=True)
    _extract_slop_phrases(
        texts               = texts,
        output_dir          = tmp_dir,
        n                   = _sf_cfg.SLOP_PHRASES_NGRAM_SIZE,          # trigram by default (3)
        top_k_ngrams        = max(1_000, how_many_new * 5),
        top_phrases_to_save = how_many_new * 3,
        chunksize           = _sf_cfg.SLOP_PHRASES_CHUNKSIZE,
    )

    phrases_jsonl = tmp_dir / "slop_list_phrases.jsonl"
    if not phrases_jsonl.exists():
        print("⚠️  Slop-Forensics did not produce a phrase file; nothing added.")
        return

    # --------------------------------------------------------------------- #
    # 2.  Load candidate phrases, filter by frequency, keep first N         #
    # --------------------------------------------------------------------- #
    new_phrases: list[str] = []
    with phrases_jsonl.open(encoding="utf-8") as fh:
        for line in fh:
            if len(new_phrases) >= how_many_new:
                break
            item = json.loads(line)
            if isinstance(item, list):
                phrase, freq = item[0], (item[1] if len(item) > 1 else 1)
            else:                             # fallback: plain string line
                phrase, freq = str(item), 1

            if freq >= MIN_PHRASE_FREQ_TO_KEEP:
                new_phrases.append(phrase)

    # --------------------------------------------------------------------- #
    # 3.  Merge with existing ban list                                      #
    # --------------------------------------------------------------------- #
    existing_phrases: set[str] = set()
    if json_path.exists():
        try:
            raw = json.loads(json_path.read_text(encoding="utf-8"))
            for entry in raw:
                if isinstance(entry, str):
                    existing_phrases.add(entry)
                elif isinstance(entry, list) and entry:
                    existing_phrases.add(str(entry[0]))
        except Exception as exc:
            print(f"⚠️  Could not read existing ban list ({json_path}): {exc}")

    merged: set[str] = existing_phrases.union(new_phrases)

    # --------------------------------------------------------------------- #
    # 4.  Add over-represented single words                      #
    # --------------------------------------------------------------------- #
    if BAN_OVERREP_WORDS_IN_PHRASE_LIST and over_represented_words:
        merged.update(over_represented_words)

    # --------------------------------------------------------------------- #
    # 5.  Save back in `[["phrase", 1], …]` format                          #
    # --------------------------------------------------------------------- #
    merged_list = sorted([[phrase, 1] for phrase in merged], key=lambda x: x[0])

    json_path.write_text(
        json.dumps(merged_list, indent=2, ensure_ascii=False),
        encoding="utf-8",
    )

    print(
        f"🚫  Slop-phrase ban list updated → {json_path}   "
        f"(now {len(merged_list)} entries; "
        f"+{len(merged) - len(existing_phrases)} new)"
    )



def _convert_and_normalize_human_ngram_list(ngram_list_of_dicts, n_value: int):
    if not isinstance(ngram_list_of_dicts, list):
        print(f"Warning: Expected a list for human {n_value}-grams, got {type(ngram_list_of_dicts)}. Returning empty dict.")
        return {}
    
    converted_dict = {}
    skipped_count = 0
    original_count = len(ngram_list_of_dicts)

    for item in ngram_list_of_dicts:
        ngram_str = item.get("ngram")
        frequency = item.get("frequency")

        if ngram_str is None or frequency is None:
            skipped_count += 1
            continue
        
        normalized_text_for_human_ngram = normalize_text(str(ngram_str))
        tokens = [t.lower() for t in nltk.word_tokenize(normalized_text_for_human_ngram) if t.isalpha()]
        
        if len(tokens) == n_value:
            processed_ngram_key = " ".join(tokens)
            converted_dict[processed_ngram_key] = converted_dict.get(processed_ngram_key, 0) + int(frequency)
        else:
            skipped_count += 1
            # print(f"Debug: Skipping human {n_value}-gram '{ngram_str}' -> tokens {tokens} (len != {n_value})")

    if skipped_count > 0 or original_count > 0 : # Print info even if no skips but items processed
        print(f"INFO: Normalizing human {n_value}-grams: Processed {original_count} items. "
              f"Resulted in {len(converted_dict)} unique normalized {n_value}-gram keys. "
              f"{skipped_count} original items were skipped or merged.")
    return converted_dict

def norm_per_100k(raw_count: int, char_total: float) -> float:
    if char_total == 0:
        return 0.0 if raw_count == 0 else math.inf
    return (raw_count / char_total) * FREQ_NORM_DENOM

def build_norm_dict(counter: Counter, char_total: float, top_k: int):
    return {
        term: {
            "gen_count": counter[term],
            "gen_freq_per_100k": norm_per_100k(counter[term], char_total)
        }
        for term, _ in counter.most_common(top_k)
    }

def compare_to_human(gen_norm: dict, human_counts: dict, human_total_chars: float):
    both, gen_only = {}, {}
    for term, data in gen_norm.items():
        if term in human_counts:
            h_raw_count = human_counts[term]
            h_freq_norm = norm_per_100k(h_raw_count, human_total_chars)
            gen_freq = data["gen_freq_per_100k"]
            ratio = math.inf
            if h_freq_norm > 0:
                ratio = gen_freq / h_freq_norm
            elif gen_freq == 0 and h_freq_norm == 0:
                ratio = 1.0
            both[term] = {**data, "human_count": h_raw_count, "human_freq_per_100k": h_freq_norm, "freq_ratio_gen/hu": ratio}
        else:
            gen_only[term] = {**data, "human_count": 0, "human_freq_per_100k": 0.0, "freq_ratio_gen/hu": math.inf}
    return both, gen_only

def analyze_iteration_outputs(generated_jsonl_path: Path, human_profile_full: dict, iter_analysis_output_dir: Path):
    """Performs n-gram analysis for a given iteration's generated texts."""
    print(f"\n--- Analyzing Outputs for {generated_jsonl_path.name} ---")
    iter_analysis_output_dir.mkdir(parents=True, exist_ok=True)

    gen_rows = load_jsonl_file(str(generated_jsonl_path))
    gen_texts = [row["generation"] for row in gen_rows if isinstance(row.get("generation"), str)]

    if not gen_texts:
        print(f"Warning: No usable text in {generated_jsonl_path}. Skipping analysis for this iteration.")
        return None, None, None, None, [], 0 # DFs, gen_texts, total_chars

    human_profile = human_profile_full.get('human-authored')
    if not human_profile:
        raise ValueError(f"Key 'human-authored' not found in human profile data.")

    human_bigrams_list = human_profile.get("top_bigrams", [])
    human_trigrams_list = human_profile.get("top_trigrams", [])
    human_bigrams = _convert_and_normalize_human_ngram_list(human_bigrams_list, 2)
    human_trigrams = _convert_and_normalize_human_ngram_list(human_trigrams_list, 3)

    required_keys = ["num_texts_analyzed", "avg_length"]
    for key in required_keys:
        if key not in human_profile:
            raise KeyError(f"Human profile JSON missing required key: '{key}'.")
    
    h_chars_total = human_profile["num_texts_analyzed"] * human_profile["avg_length"]
    if h_chars_total == 0:
        print(f"Warning: Total characters for human data (h_chars_total) is 0.")

    # Word counts & N-gram counts (LLM output)
    word_counter = Counter()
    total_chars = sum(len(txt) for txt in gen_texts)
    
    for txt in gen_texts:
        norm_t = normalize_text(txt)
        word_counter.update(w for w in extract_words(norm_t, MIN_WORD_LEN) if w not in STOP_WORDS)

    bigram_counter = Counter()
    trigram_counter = Counter()
    for txt in gen_texts:
        normalized_llm_text = normalize_text(txt)
        tokens_all = [t.lower() for t in nltk.word_tokenize(normalized_llm_text) if t.isalpha()]
        tokens = [tok for tok in tokens_all if tok not in STOP_WORDS and (len(tok) >= MIN_WORD_LEN or tok in {"it's"})]
        bigram_counter.update(" ".join(bg) for bg in ngrams(tokens, 2))
        trigram_counter.update(" ".join(tg) for tg in ngrams(tokens, 3))

    # Normalise
    gen_bigrams_norm = build_norm_dict(bigram_counter, float(total_chars), TOP_K_BIGRAMS)
    gen_trigrams_norm = build_norm_dict(trigram_counter, float(total_chars), TOP_K_TRIGRAMS)

    # Merge with human profile
    bigrams_dict, bigrams_nondict = compare_to_human(gen_bigrams_norm, human_bigrams, h_chars_total)
    trigrams_dict, trigrams_nondict = compare_to_human(gen_trigrams_norm, human_trigrams, h_chars_total)

    # Create DataFrames
    df_bi_dict = pd.DataFrame.from_dict(bigrams_dict, orient="index")
    df_bi_nondct = pd.DataFrame.from_dict(bigrams_nondict, orient="index")
    df_tri_dict = pd.DataFrame.from_dict(trigrams_dict, orient="index")
    df_tri_nondct = pd.DataFrame.from_dict(trigrams_nondict, orient="index")

    # Sort
    if not df_bi_dict.empty and "freq_ratio_gen/hu" in df_bi_dict.columns:
        df_bi_dict.sort_values(by="freq_ratio_gen/hu", ascending=False, inplace=True)
    if not df_tri_dict.empty and "freq_ratio_gen/hu" in df_tri_dict.columns:
        df_tri_dict.sort_values(by="freq_ratio_gen/hu", ascending=False, inplace=True)
    # Non-dictionary DFs are already sorted by gen_count implicitly by most_common

    # Save CSVs
    df_bi_dict.to_csv(iter_analysis_output_dir / "bigrams__dictionary_sorted.csv")
    df_bi_nondct.to_csv(iter_analysis_output_dir / "bigrams__non_dictionary.csv")
    df_tri_dict.to_csv(iter_analysis_output_dir / "trigrams__dictionary_sorted.csv")
    df_tri_nondct.to_csv(iter_analysis_output_dir / "trigrams__non_dictionary.csv")
    print(f"N-gram analysis CSVs written to {iter_analysis_output_dir.resolve()}")

    return df_bi_dict, df_bi_nondct, df_tri_dict, df_tri_nondct, gen_texts, total_chars


def update_banned_ngrams_list(banned_ngrams_json_path: Path, 
                              dfs: list, # [df_bi_dict, df_bi_nondct, df_tri_dict, df_tri_nondct]
                              num_to_take: int, 
                              is_first_iteration: bool):
    """Updates the JSON file with banned n-grams."""
    newly_banned_ngrams = set()
    
    # df_bi_dict, df_bi_nondct, df_tri_dict, df_tri_nondct
    if not dfs[0].empty: # df_bi_dict
        newly_banned_ngrams.update(dfs[0].head(num_to_take).index.tolist())
    if not dfs[1].empty: # df_bi_nondct
        newly_banned_ngrams.update(dfs[1].head(num_to_take).index.tolist())
    if not dfs[2].empty: # df_tri_dict
        newly_banned_ngrams.update(dfs[2].head(num_to_take).index.tolist())
    if not dfs[3].empty: # df_tri_nondct
        newly_banned_ngrams.update(dfs[3].head(num_to_take).index.tolist())

    current_banned_list = []
    if not is_first_iteration and banned_ngrams_json_path.exists():
        with open(banned_ngrams_json_path, 'r', encoding='utf-8') as f:
            current_banned_list = json.load(f)
    
    # Add new n-grams, ensuring uniqueness and maintaining order for consistency (though set ops remove order)
    # Convert to set for efficient addition, then back to list for JSON serialization
    updated_banned_set = set(current_banned_list)
    updated_banned_set.update(newly_banned_ngrams)
    
    final_banned_list = sorted(list(updated_banned_set)) # Sort for consistent file output

    with open(banned_ngrams_json_path, 'w', encoding='utf-8') as f:
        json.dump(final_banned_list, f, indent=4)
    
    print(f"Updated banned n-grams list at {banned_ngrams_json_path}. Total banned: {len(final_banned_list)}.")
    if is_first_iteration:
        print(f"Added {len(newly_banned_ngrams)} n-grams from initial run.")
    else:
        added_count = len(final_banned_list) - len(current_banned_list)
        print(f"Added {added_count} new unique n-grams to the list.")


def calculate_lexical_diversity_stats(gen_texts: list):
    """Calculates TTR and Root TTR for a list of texts."""
    if not gen_texts:
        return 0.0, 0.0

    all_words = []
    for text in gen_texts:
        normalized_text = normalize_text(text) # Basic normalization
        tokens = [t.lower() for t in nltk.word_tokenize(normalized_text) if t.isalpha() and len(t) > 1] # Alpha, len > 1
        all_words.extend(tokens)
    
    if not all_words:
        return 0.0, 0.0

    num_tokens = len(all_words)
    num_types = len(set(all_words))

    ttr = num_types / num_tokens if num_tokens > 0 else 0.0
    rttr = num_types / math.sqrt(num_tokens) if num_tokens > 0 else 0.0
    
    return ttr, rttr

def calculate_repetition_score(gen_texts: list, total_chars: int, iteration_dfs: list):
    """
    Counts occurrences of top N n-grams from this iteration's analysis within this iteration's texts.
    iteration_dfs: [df_bi_dict, df_bi_nondct, df_tri_dict, df_tri_nondct] for the current iteration.
    """
    if not gen_texts or total_chars == 0:
        return 0.0

    target_ngrams_for_repetition = set()
    # df_bi_dict, df_bi_nondct, df_tri_dict, df_tri_nondct
    if not iteration_dfs[0].empty:
        target_ngrams_for_repetition.update(iteration_dfs[0].head(TOP_N_REPETITION_STAT).index.tolist())
    if not iteration_dfs[1].empty:
        target_ngrams_for_repetition.update(iteration_dfs[1].head(TOP_N_REPETITION_STAT).index.tolist())
    if not iteration_dfs[2].empty:
        target_ngrams_for_repetition.update(iteration_dfs[2].head(TOP_N_REPETITION_STAT).index.tolist())
    if not iteration_dfs[3].empty:
        target_ngrams_for_repetition.update(iteration_dfs[3].head(TOP_N_REPETITION_STAT).index.tolist())

    if not target_ngrams_for_repetition:
        return 0.0

    total_repetition_instances = 0
    for text in gen_texts:
        normalized_text = normalize_text(text)
        # Tokenize consistent with n-gram generation in analyze_iteration_outputs
        tokens_all = [t.lower() for t in nltk.word_tokenize(normalized_text) if t.isalpha()]
        tokens = [tok for tok in tokens_all if tok not in STOP_WORDS and (len(tok) >= MIN_WORD_LEN or tok in {"it's"})]

        current_bigrams = [" ".join(bg) for bg in ngrams(tokens, 2)]
        current_trigrams = [" ".join(tg) for tg in ngrams(tokens, 3)]

        for bg in current_bigrams:
            if bg in target_ngrams_for_repetition:
                total_repetition_instances += 1
        for tg in current_trigrams:
            if tg in target_ngrams_for_repetition:
                total_repetition_instances += 1
    
    repetition_score_normalized = norm_per_100k(total_repetition_instances, float(total_chars))
    return repetition_score_normalized

# --------------------------------------------------------------------- #
# 3)  BUILD DPO DATASET (iteration-0 vs final iteration)                 #
# --------------------------------------------------------------------- #
def create_dpo_dataset(
    iter0_jsonl: Path,
    final_iter_jsonl: Path,
    output_jsonl: Path,
) -> None:
    """
    Writes a JSONL file where each line is:
        {"prompt": <cleaned_prompt>,
            "chosen":  <final_iter_generation>,
            "rejected":<iter0_generation>}
    Prompts present in only one of the two files are skipped.
    """
    KEY_PROMPT     = "prompt"       # ← change if your field name differs
    KEY_PROMPT_ID  = "prompt_id"    # ← optional; fallback is cleaned prompt

    def _strip_wrapping(text: str) -> str:
        # Remove the exact boiler-plate prefix / suffix requested
        prefix = "Writing prompt: "
        suffix = "\n\nWrite 1000 words to this prompt. Your response:\n"
        if text.startswith(prefix):
            text = text[len(prefix):]
        if text.endswith(suffix):
            text = text[: -len(suffix)]
        return text.strip()

    def _load_file(path: Path) -> dict:
        """Returns dict[key → {"prompt":prompt, "generation":gen}]"""
        out = {}
        with path.open(encoding="utf-8") as fh:
            for row_raw in fh:
                try:
                    row = json.loads(row_raw)
                except json.JSONDecodeError:
                    continue
                prompt_raw = row.get(KEY_PROMPT, "")
                gen        = row.get("generation", "")
                if not prompt_raw or not gen:
                    continue
                prompt_clean = _strip_wrapping(prompt_raw)
                # Prefer explicit prompt_id if present and stable
                key = row.get(KEY_PROMPT_ID, prompt_clean)
                out[key] = {"prompt": prompt_clean, "generation": gen}
        return out

    data_iter0   = _load_file(iter0_jsonl)
    data_final   = _load_file(final_iter_jsonl)
    common_keys  = data_iter0.keys() & data_final.keys()

    if not common_keys:
        print("⚠️  No overlapping prompts between iteration-0 and the final "
                "iteration; DPO dataset not written.")
        return

    with output_jsonl.open("w", encoding="utf-8") as out_fh:
        for key in common_keys:
            rec = {
                "prompt":   data_iter0[key]["prompt"],  # same cleaned prompt
                "chosen":   data_final[key]["generation"],
                "rejected": data_iter0[key]["generation"],
            }
            json.dump(rec, out_fh, ensure_ascii=False)
            out_fh.write("\n")

    print(f"📁  DPO dataset written → {output_jsonl} "
            f"({len(common_keys)} prompt pairs)")

# %%
##################################
# Main Pipeline Execution        #
##################################
def antislop_pipeline() -> None:
    """
    Run the multi-iteration anti-slop experiment.

    What this does
    --------------
    • For each iteration:
        1.  Generate LLM outputs with main.py
              – forwards `--ngram-banned-file` (classic anti-slop)
              – forwards `--slop-phrases-file` (Slop-Forensics ban list)
        2.  Analyse outputs vs. human profile:
              – bigrams / trigrams (dict & non-dict)
              – over-represented single words (via Slop-Forensics)
        3.  Update *two* growing ban lists
              a) banned_ngrams.json     (top 300 → 100 rule, freq>1 only)
              b) banned_slop_phrases.json
                 ▸ top 200 → 100 phrases (freq>1 only)
                 ▸ optionally also over-rep words
        4.  Collect lexical-diversity & repetition metrics.

    Outputs
    -------
    • per-iteration analysis CSVs
    • over-represented-word CSVs
    • `banned_ngrams.json`
    • `banned_slop_phrases.json`
    • `final_iteration_statistics.csv`
    """
    # -------------------------------------------------------------------------#
    # 0) PRE-RUN CHECKS & FOLDERS                                              #
    # -------------------------------------------------------------------------#
    if not HUMAN_PROFILE_PATH.exists():
        print(f"ERROR: human profile JSON not found → {HUMAN_PROFILE_PATH}")
        return

    with HUMAN_PROFILE_PATH.open("r", encoding="utf-8") as f_hp:
        human_profile_full: dict = json.load(f_hp)

    timestamp: str = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    experiment_dir: Path = EXPERIMENT_BASE_DIR / f"run_{timestamp}"
    experiment_dir.mkdir(parents=True, exist_ok=True)
    print(f"\n📂  Experiment directory: {experiment_dir.resolve()}")

    banned_ngrams_json_path:      Path = experiment_dir / "banned_ngrams.json"
    banned_slop_phrases_json_path: Path = experiment_dir / "banned_slop_phrases.json"

    iteration_stats: list[dict] = []   # rows for final CSV

    # -------------------------------------------------------------------------#
    # 1) ITERATIVE LOOP                                                        #
    # -------------------------------------------------------------------------#
    for iter_idx in range(NUM_ITERATIONS):
        print(f"\n{'='*30}  ITERATION {iter_idx}  {'='*30}")

        # --- paths -----------------------------------------------------------
        iter_output_jsonl: Path = experiment_dir / (
            f"iter_{iter_idx}_creative_writing_generations.jsonl"
        )
        iter_analysis_dir: Path = experiment_dir / f"iter_{iter_idx}_analysis_results"
        iter_analysis_dir.mkdir(parents=True, exist_ok=True)

        # --- decide which ban lists to pass this round -----------------------
        ngram_file_for_cli:       Path | None = None
        slop_phrase_file_for_cli: Path | None = None
        top_n_slop_phrase_flag:   int  | None = None

        if iter_idx > 0:
            if banned_ngrams_json_path.exists():
                ngram_file_for_cli = banned_ngrams_json_path
            if banned_slop_phrases_json_path.exists():
                slop_phrase_file_for_cli = banned_slop_phrases_json_path
                top_n_slop_phrase_flag  = 999_999   # “ban every phrase in file”

        # --- GENERATE TEXTS --------------------------------------------------
        run_generation_script(
            iter_idx                = iter_idx,
            output_jsonl_path       = iter_output_jsonl,
            banned_ngrams_file_path = ngram_file_for_cli,       # NEW restored flag
            slop_phrases_file_path  = slop_phrase_file_for_cli, # phrase ban list
            top_n_slop_phrases      = top_n_slop_phrase_flag or 0,
        )

        # --- ANALYSE TEXTS ---------------------------------------------------
        (df_bi_dict,
         df_bi_nondict,
         df_tri_dict,
         df_tri_nondict,
         generated_texts,
         total_generated_chars) = analyze_iteration_outputs(
             generated_jsonl_path     = iter_output_jsonl,
             human_profile_full       = human_profile_full,
             iter_analysis_output_dir = iter_analysis_dir,
         )

        # If generation/analysis failed, record empty stats and continue
        if df_bi_dict is None:
            iteration_stats.append({
                "iteration":             iter_idx,
                "generated_text_count":  0,
                "generated_char_count":  0,
                "ttr":                   0.0,
                "rttr":                  0.0,
                "repetition_per_100k":   0.0,
                "output_file":           str(iter_output_jsonl),
            })
            continue

        # --- OVER-REPRESENTED WORDS (Slop-Forensics) -------------------------
        overrep_tokens_for_ban: list[str] = []
        if COMPUTE_OVERREP_WORDS:
            overrep_csv: Path = iter_analysis_dir / "overrepresented_words.csv"
            df_overrep, dict_words, nodict_words = build_overrep_word_csv(
                texts   = generated_texts,
                out_csv = overrep_csv,
                top_n   = TOP_K_WORDS,
            )
            overrep_tokens_for_ban = select_overrep_words_for_ban(
                dict_words       = dict_words,
                nodict_words     = nodict_words,
                is_first_iteration = (iter_idx == 0)
            )

        # --- UPDATE ① N-GRAM BAN LIST ------------------------------
        if ENABLE_NGRAM_BAN:
            n_to_ban = TOP_N_INITIAL_BAN if iter_idx == 0 else TOP_N_SUBSEQUENT_BAN
            update_banned_ngrams_list(
                banned_ngrams_json_path,
                dfs=[df_bi_dict, df_bi_nondict, df_tri_dict, df_tri_nondict],
                num_to_take=n_to_ban,
                is_first_iteration=(iter_idx == 0),
            )

        # --- UPDATE ② SLOP-PHRASE BAN LIST -----------------------------------
        if ENABLE_SLOP_PHRASE_BAN:
            phrases_to_add = TOP_N_INITIAL_SLOP_BAN if iter_idx == 0 else TOP_N_SUBSEQUENT_SLOP_BAN
            update_banned_slop_phrases(
                json_path   = banned_slop_phrases_json_path,
                texts       = generated_texts,
                how_many_new= phrases_to_add,
                tmp_dir     = iter_analysis_dir / "phrase_tmp",
                over_represented_words= overrep_tokens_for_ban,
            )

        # --- LEXICAL-DIVERSITY & REPETITION METRICS --------------------------
        ttr, rttr           = calculate_lexical_diversity_stats(generated_texts)
        repetition_norm     = calculate_repetition_score(
            gen_texts     = generated_texts,
            total_chars   = total_generated_chars,
            iteration_dfs = [df_bi_dict, df_bi_nondict, df_tri_dict, df_tri_nondict],
        )

        iteration_stats.append({
            "iteration":             iter_idx,
            "generated_text_count":  len(generated_texts),
            "generated_char_count":  total_generated_chars,
            "ttr":                   ttr,
            "rttr":                  rttr,
            "repetition_per_100k":   repetition_norm,
            "output_file":           str(iter_output_jsonl),
        })

    # -------------------------------------------------------------------------#
    # 2) FINAL SUMMARY CSV                                                     #
    # -------------------------------------------------------------------------#
    summary_df: pd.DataFrame = pd.DataFrame(iteration_stats)
    summary_csv: Path        = experiment_dir / "final_iteration_statistics.csv"
    summary_df.to_csv(summary_csv, index=False)

    # --------------------------------------------------------------------- #
    # 4)  CALL THE DPO DATASET CREATOR                                       #
    # --------------------------------------------------------------------- #
    if NUM_ITERATIONS >= 2:
        iter0_file     = experiment_dir / "iter_0_creative_writing_generations.jsonl"
        last_iter_idx  = NUM_ITERATIONS - 1
        final_file     = experiment_dir / f"iter_{last_iter_idx}_creative_writing_generations.jsonl"
        dpo_output     = experiment_dir / "dpo_pairs_dataset.jsonl"
        create_dpo_dataset(iter0_file, final_file, dpo_output)
    else:
        print("⚠️  Need at least two iterations to build DPO pairs; skipped.")

    print(f"\n📊  Final statistics written → {summary_csv.resolve()}")
    print(summary_df.to_string(index=False))

if __name__ == "__main__" and RUN_PIPELINE:
    # This check allows the notebook to be imported without running the pipeline,
    # or run directly if executed as a script (though it's a .ipynb file).
    # In Jupyter, you'd just run the cell containing antislop_pipeline().
    
    # For direct execution from command line (e.g. `python your_notebook.ipynb` via jupytext or similar)
    # Or if you convert this to a .py script
    
    # Check if main.py exists
    if not Path("main.py").exists():
        print("Error: main.py not found in the current directory.")
        print("Please ensure main.py (the generation script) is present.")
        # sys.exit(1) # Exit if running as script and main.py is missing
        # For notebook, we might want to proceed to define functions even if main.py is missing,
        # so commenting out sys.exit. The run_generation_script will fail later.
    
    antislop_pipeline()

elif not RUN_PIPELINE:
    print("RUN_PIPELINE is False. Pipeline execution skipped.")
    print("You can manually call functions or inspect parameters.")
# Out:
# NLTK 'punkt' resource found.
# Warning: Could not automatically verify/download NLTK 'punkt_tab' resource: No such file or directory: '/home/sam/nltk_data/tokenizers/punkt/PY3_tab'.
# NLTK 'stopwords' resource found.
# Successfully imported from slop_forensics.utils
# Loaded 198 NLTK stopwords for 'english'.
#
# 📂  Experiment directory: /home/sam/code/ai/antislop-api/results/iterative_antislop_experiment/run_20250510_090827
#
# ==============================  ITERATION 0  ==============================
#
# ┏━━ Iteration 0: launching main.py ━━━━━━━━━━━━━━━━━━━━━━┓
# /usr/bin/python3 main.py --output-jsonl results/iterative_antislop_experiment/run_20250510_090827/iter_0_creative_writing_generations.jsonl --input-hf-dataset Nitral-AI/Reddit-SFW-Writing_Prompts_ShareGPT --hf-dataset-split train --threads 80 --max-prompts 80 --logging-level INFO
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# INFO mode: Progress bar and ban events will be printed. Most logs suppressed. Effective script level: INFO
# Extracting HF prompts:   0%|          | 79/177477 [00:00<00:12, 13775.83prompt/s]
# Preparing to process 80 new prompts in this run.
# Batch Generating: 100%|██████████| 80/80 [00:27<00:00,  2.95prompt/s, 1771.3 tok/s]
# Finished processing 80 prompts in this run in 27.10s.
# Overall average throughput for this run: 1770.99 tok/s.
# Results appended to results/iterative_antislop_experiment/run_20250510_090827/iter_0_creative_writing_generations.jsonl
# ✅  main.py finished — output saved to results/iterative_antislop_experiment/run_20250510_090827/iter_0_creative_writing_generations.jsonl
#
# --- Analyzing Outputs for iter_0_creative_writing_generations.jsonl ---
# INFO: Normalizing human 2-grams: Processed 200000 items. Resulted in 200000 unique normalized 2-gram keys. 0 original items were skipped or merged.
# INFO: Normalizing human 3-grams: Processed 200000 items. Resulted in 200000 unique normalized 3-gram keys. 0 original items were skipped or merged.
# N-gram analysis CSVs written to /home/sam/code/ai/antislop-api/results/iterative_antislop_experiment/run_20250510_090827/iter_0_analysis_results
# 🔎  over-rep word CSV → results/iterative_antislop_experiment/run_20250510_090827/iter_0_analysis_results/overrepresented_words.csv  (6186 rows)
# Updated banned n-grams list at results/iterative_antislop_experiment/run_20250510_090827/banned_ngrams.json. Total banned: 945.
# Added 945 n-grams from initial run.
# MP substring extraction: 100%|██████████| 80/80 [00:00<00:00, 596.67it/s]
# 🚫  Slop-phrase ban list updated → results/iterative_antislop_experiment/run_20250510_090827/banned_slop_phrases.json   (now 564 entries; +564 new)
#
# ==============================  ITERATION 1  ==============================
#
# ┏━━ Iteration 1: launching main.py ━━━━━━━━━━━━━━━━━━━━━━┓
# /usr/bin/python3 main.py --output-jsonl results/iterative_antislop_experiment/run_20250510_090827/iter_1_creative_writing_generations.jsonl --input-hf-dataset Nitral-AI/Reddit-SFW-Writing_Prompts_ShareGPT --hf-dataset-split train --threads 80 --max-prompts 80 --logging-level INFO --ngram-banned-file results/iterative_antislop_experiment/run_20250510_090827/banned_ngrams.json --slop-phrases-file results/iterative_antislop_experiment/run_20250510_090827/banned_slop_phrases.json --top-n-slop-phrases 999999
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# INFO mode: Progress bar and ban events will be printed. Most logs suppressed. Effective script level: INFO
# Extracting HF prompts:   0%|          | 79/177477 [00:00<00:04, 40153.90prompt/s]
# Preparing to process 80 new prompts in this run.
# BANNED (prompt_idx=17, type=slop_phrase, phrase='pulsing')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='rain smelled of ozone')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='veridia')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='rain smelled of iron')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='rain hammered against the windows')
# BANNED (prompt_idx=20, type=slop_phrase, phrase='rain smelled of iron')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='greasy, insistent thing')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='rain tasted like')
# BANNED (prompt_idx=3, type=ngram, ngram='rain fell')
# BANNED (prompt_idx=62, type=ngram, ngram='bruised purple')
# BANNED (prompt_idx=5, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='veridian')
# BANNED (prompt_idx=67, type=ngram, ngram='rain greasy')
# BANNED (prompt_idx=26, type=ngram, ngram='rain tasted')
# BANNED (prompt_idx=1, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=9, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=0, type=slop_phrase, phrase='greasy, insistent thing')
# BANNED (prompt_idx=72, type=slop_phrase, phrase='hammered')
# BANNED (prompt_idx=75, type=slop_phrase, phrase='rain smelled like')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='tasted like regret')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='veridia')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='rain tasted like')
# BANNED (prompt_idx=13, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=11, type=slop_phrase, phrase='rain hammered against the windows')
# BANNED (prompt_idx=27, type=ngram, ngram='rain greasy insistent')
# BANNED (prompt_idx=8, type=slop_phrase, phrase='mirroring')
# BANNED (prompt_idx=7, type=ngram, ngram='dust motes danced')
# BANNED (prompt_idx=28, type=slop_phrase, phrase='rain smelled of ozone')
# BANNED (prompt_idx=71, type=slop_phrase, phrase='rain smelled like')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='oakhaven')
# BANNED (prompt_idx=68, type=ngram, ngram='tasted like')
# BANNED (prompt_idx=38, type=slop_phrase, phrase='viscous')
# BANNED (prompt_idx=53, type=ngram, ngram='rain tasted')
# BANNED (prompt_idx=54, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='rain smelled like')
# BANNED (prompt_idx=48, type=slop_phrase, phrase='woodsmoke')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='jingled')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='beige')
# BANNED (prompt_idx=43, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=52, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='rain tasted like')
# BANNED (prompt_idx=19, type=slop_phrase, phrase='shimmered')
# BANNED (prompt_idx=21, type=ngram, ngram='rain smelled')
# BANNED (prompt_idx=61, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=18, type=slop_phrase, phrase='rain smelled like')
# BANNED (prompt_idx=16, type=ngram, ngram='last thing remembered')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=31, type=ngram, ngram='rain xylos')
# BANNED (prompt_idx=69, type=ngram, ngram='rain smelled like')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='rain smelled like')
# BANNED (prompt_idx=79, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=32, type=slop_phrase, phrase='rain smelled of ozone')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='veridia')
# BANNED (prompt_idx=36, type=ngram, ngram='rain xylos')
# BANNED (prompt_idx=24, type=ngram, ngram='rain greasy')
# BANNED (prompt_idx=70, type=slop_phrase, phrase='rain smelled like')
# BANNED (prompt_idx=33, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=37, type=slop_phrase, phrase='rain tasted like')
# BANNED (prompt_idx=39, type=ngram, ngram='rain greasy')
# BANNED (prompt_idx=47, type=slop_phrase, phrase='hissed')
# BANNED (prompt_idx=10, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=59, type=ngram, ngram='temporal displacement')
# BANNED (prompt_idx=12, type=slop_phrase, phrase='xylos')
# BANNED (prompt_idx=42, type=slop_phrase, phrase='rain smelled of iron')
# BANNED (prompt_idx=55, type=ngram, ngram='downpour persistent')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=41, type=slop_phrase, phrase='rain smelled of rust')
# BANNED (prompt_idx=57, type=ngram, ngram='bruised purple')
# BANNED (prompt_idx=40, type=slop_phrase, phrase='flappy')
# BANNED (prompt_idx=17, type=slop_phrase, phrase='resonant')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='perpetually')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='rain smelled of iron')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='always smelled of regret')
# BANNED (prompt_idx=45, type=slop_phrase, phrase='hissed')
# BANNED (prompt_idx=34, type=slop_phrase, phrase='shimmered')
# BANNED (prompt_idx=50, type=slop_phrase, phrase='rain smelled of rust')
# BANNED (prompt_idx=46, type=ngram, ngram='dust motes danced')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='murmur')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=20, type=ngram, ngram='dust motes danced')
# BANNED (prompt_idx=65, type=ngram, ngram='persistent grey')
# BANNED (prompt_idx=63, type=ngram, ngram='dust motes danced')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='rain in aethelgard always')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=5, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=67, type=ngram, ngram='metallic tang')
# BANNED (prompt_idx=1, type=ngram, ngram='bruised purple')
# BANNED (prompt_idx=26, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=9, type=slop_phrase, phrase='echoing')
# BANNED (prompt_idx=0, type=slop_phrase, phrase='insistent thing, clinging')
# BANNED (prompt_idx=72, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=75, type=slop_phrase, phrase='perpetually')
# BANNED (prompt_idx=13, type=slop_phrase, phrase='lingering')
# BANNED (prompt_idx=11, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=28, type=slop_phrase, phrase='ozone')
# BANNED (prompt_idx=38, type=ngram, ngram='like particularly')
# BANNED (prompt_idx=27, type=slop_phrase, phrase='crackled')
# BANNED (prompt_idx=7, type=slop_phrase, phrase='rain hammered against the windows')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='first thing i noticed')
# BANNED (prompt_idx=48, type=ngram, ngram='something vaguely')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='hung thick with the scent')
# BANNED (prompt_idx=43, type=ngram, ngram='neon glow')
# BANNED (prompt_idx=19, type=ngram, ngram='arrived precisely')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='damp')
# BANNED (prompt_idx=8, type=slop_phrase, phrase='dampness')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='cobblestones')
# BANNED (prompt_idx=54, type=slop_phrase, phrase='shimmered')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='muttered')
# BANNED (prompt_idx=25, type=ngram, ngram='eighteen years')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='rain in havenwood always')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='ozone')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='aethel')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='tasted like regret')
# BANNED (prompt_idx=18, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=69, type=slop_phrase, phrase='thrum')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=31, type=slop_phrase, phrase='xylos')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='thrum')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='obsidian')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='smelled of iron and regret')
# BANNED (prompt_idx=70, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=33, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=47, type=slop_phrase, phrase='crackled')
# BANNED (prompt_idx=39, type=slop_phrase, phrase='tasted like regret')
# BANNED (prompt_idx=32, type=slop_phrase, phrase='first thing i noticed')
# BANNED (prompt_idx=37, type=slop_phrase, phrase='crumbling')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='tasted like rust')
# BANNED (prompt_idx=10, type=slop_phrase, phrase='first thing i noticed')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=12, type=ngram, ngram='observation deck')
# BANNED (prompt_idx=42, type=ngram, ngram='slow deliberate')
# BANNED (prompt_idx=59, type=slop_phrase, phrase='woodsmoke')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='something vaguely metallic')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=41, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='aethelburg')
# BANNED (prompt_idx=40, type=slop_phrase, phrase='flappy')
# BANNED (prompt_idx=55, type=ngram, ngram='persistent grey')
# BANNED (prompt_idx=17, type=ngram, ngram='carefully constructed')
# BANNED (prompt_idx=6, type=ngram, ngram='started subtly')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='weariness')
# BANNED (prompt_idx=20, type=ngram, ngram='rain smelled')
# BANNED (prompt_idx=45, type=slop_phrase, phrase='first thing i noticed')
# BANNED (prompt_idx=34, type=slop_phrase, phrase='flickered')
# BANNED (prompt_idx=57, type=ngram, ngram='persistent grey')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='melancholic')
# BANNED (prompt_idx=46, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=50, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=2, type=ngram, ngram='violent cleansing')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='rain smelled of rust')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='mirroring')
# BANNED (prompt_idx=5, type=slop_phrase, phrase='damp')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='elias')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=67, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=26, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=1, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=0, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=72, type=slop_phrase, phrase='blurring')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=75, type=ngram, ngram='quiet desperation')
# BANNED (prompt_idx=13, type=slop_phrase, phrase='yeasty')
# BANNED (prompt_idx=38, type=ngram, ngram='particularly stubborn')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='rain hammered against the windows')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='undeniably')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='vibrated')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=7, type=ngram, ngram='dust motes danced')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='three days since')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=11, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=8, type=ngram, ngram='dull ache')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='griffins')
# BANNED (prompt_idx=25, type=ngram, ngram='slow deliberate')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='veridia')
# BANNED (prompt_idx=69, type=ngram, ngram='temporal displacement')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='thrum')
# BANNED (prompt_idx=47, type=slop_phrase, phrase='thrum')
# BANNED (prompt_idx=32, type=slop_phrase, phrase='thrum')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='greasy')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=37, type=ngram, ngram='skeletal remains')
# BANNED (prompt_idx=33, type=slop_phrase, phrase='simmering')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='mournful')
# BANNED (prompt_idx=43, type=slop_phrase, phrase='holographic')
# BANNED (prompt_idx=52, type=ngram, ngram='thick scent')
# BANNED (prompt_idx=27, type=slop_phrase, phrase='drumming')
# BANNED (prompt_idx=42, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=48, type=ngram, ngram='temporal displacement')
# BANNED (prompt_idx=31, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='ozone')
# BANNED (prompt_idx=70, type=ngram, ngram='smile playing')
# BANNED (prompt_idx=10, type=slop_phrase, phrase='damp')
# BANNED (prompt_idx=54, type=slop_phrase, phrase='flickered')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='disconcerting')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=18, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=12, type=slop_phrase, phrase='xylos')
# BANNED (prompt_idx=59, type=ngram, ngram='something vaguely')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='vibrated')
# BANNED (prompt_idx=55, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='veridia')
# BANNED (prompt_idx=41, type=ngram, ngram='skeletal remains')
# BANNED (prompt_idx=57, type=ngram, ngram='bruised purple')
# BANNED (prompt_idx=20, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=45, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='subtly')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=17, type=slop_phrase, phrase='primal')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='drizzle that clung to everything')
# BANNED (prompt_idx=67, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=50, type=slop_phrase, phrase='carefully constructed façade')
# BANNED (prompt_idx=34, type=slop_phrase, phrase='agonizingly')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=62, type=ngram, ngram='last months')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='riad')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='obsidian')
# BANNED (prompt_idx=40, type=slop_phrase, phrase='flappy')
# BANNED (prompt_idx=26, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=1, type=ngram, ngram='persistent grey')
# BANNED (prompt_idx=5, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=75, type=ngram, ngram='life spent')
# BANNED (prompt_idx=71, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=0, type=ngram, ngram='thing clinging')
# BANNED (prompt_idx=72, type=slop_phrase, phrase='lingering')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='thrummed')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='first thing i noticed')
# BANNED (prompt_idx=7, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='lingering')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='perpetually')
# BANNED (prompt_idx=37, type=ngram, ngram='skeletal remains')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='melancholic')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='murmur')
# BANNED (prompt_idx=31, type=slop_phrase, phrase='vorlag')
# BANNED (prompt_idx=70, type=slop_phrase, phrase='layin')
# BANNED (prompt_idx=39, type=ngram, ngram='name silas')
# BANNED (prompt_idx=55, type=ngram, ngram='persistent grey')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=47, type=slop_phrase, phrase='obsidian')
# BANNED (prompt_idx=11, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=18, type=ngram, ngram='force nature')
# BANNED (prompt_idx=79, type=ngram, ngram='regret familiar')
# BANNED (prompt_idx=45, type=ngram, ngram='started subtly')
# BANNED (prompt_idx=2, type=ngram, ngram='persistent grey')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=50, type=ngram, ngram='dull ache')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='lukewarm')
# BANNED (prompt_idx=34, type=slop_phrase, phrase='agonizingly')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='streaked')
# BANNED (prompt_idx=1, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=67, type=slop_phrase, phrase='beige')
# BANNED (prompt_idx=63, type=ngram, ngram='tilted head')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='fauns')
# BANNED (prompt_idx=8, type=ngram, ngram='three weeks')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='veridia')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='unsettling')
# BANNED (prompt_idx=32, type=ngram, ngram='constant reminder')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='greasy')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=16, type=ngram, ngram='like ozone')
# BANNED (prompt_idx=69, type=slop_phrase, phrase='calibrating')
# BANNED (prompt_idx=42, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=12, type=slop_phrase, phrase='thrum')
# BANNED (prompt_idx=28, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=59, type=slop_phrase, phrase='spent the last six')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='mirroring')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='aethelburg')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='viscous')
# BANNED (prompt_idx=40, type=slop_phrase, phrase='flappy')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='vorlag')
# BANNED (prompt_idx=41, type=ngram, ngram='skeletal remains')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=0, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=46, type=slop_phrase, phrase='vastness')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=43, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='thrummed')
# BANNED (prompt_idx=48, type=ngram, ngram='existential dread')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=57, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=26, type=slop_phrase, phrase='etched')
# BANNED (prompt_idx=5, type=slop_phrase, phrase='damp')
# BANNED (prompt_idx=20, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=71, type=slop_phrase, phrase='spent the last three')
# BANNED (prompt_idx=10, type=ngram, ngram='thick viscous')
# BANNED (prompt_idx=75, type=slop_phrase, phrase='blackwood')
# BANNED (prompt_idx=13, type=slop_phrase, phrase='unwavering')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=72, type=ngram, ngram='knuckles white')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='lingering')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='vibrated')
# BANNED (prompt_idx=58, type=ngram, ngram='life lived')
# BANNED (prompt_idx=7, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='elias')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='lingering')
# BANNED (prompt_idx=55, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='melancholic')
# BANNED (prompt_idx=33, type=ngram, ngram='desperate attempt')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='clatter')
# BANNED (prompt_idx=31, type=ngram, ngram='particularly unpleasant')
# BANNED (prompt_idx=27, type=slop_phrase, phrase='thorne')
# BANNED (prompt_idx=37, type=ngram, ngram='skeletal remains')
# BANNED (prompt_idx=1, type=ngram, ngram='panoramic windows')
# BANNED (prompt_idx=22, type=ngram, ngram='slow deliberate')
# BANNED (prompt_idx=50, type=ngram, ngram='carefully constructed')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=34, type=ngram, ngram='grown accustomed')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='howled')
# BANNED (prompt_idx=8, type=ngram, ngram='three weeks')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='pulsed')
# BANNED (prompt_idx=19, type=ngram, ngram='particularly stubborn')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='mournful')
# BANNED (prompt_idx=18, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=67, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='disconcerting')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='greasy')
# BANNED (prompt_idx=45, type=ngram, ngram='dust motes')
# BANNED (prompt_idx=70, type=slop_phrase, phrase='sourdough')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='griffins')
# BANNED (prompt_idx=25, type=ngram, ngram='steady rhythm')
# BANNED (prompt_idx=69, type=slop_phrase, phrase='chronometer')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='perpetually')
# BANNED (prompt_idx=40, type=slop_phrase, phrase='lurched')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='blinked')
# BANNED (prompt_idx=12, type=ngram, ngram='constant thrum')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='overlaid')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='oakhaven')
# BANNED (prompt_idx=28, type=ngram, ngram='name silas')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='whispered')
# BANNED (prompt_idx=57, type=slop_phrase, phrase='mirroring')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=9, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=65, type=ngram, ngram='something akin')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='plastered')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=71, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=17, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=76, type=ngram, ngram='grown accustomed')
# BANNED (prompt_idx=26, type=ngram, ngram='spent last')
# BANNED (prompt_idx=46, type=ngram, ngram='name silas')
# BANNED (prompt_idx=53, type=ngram, ngram='quiet almost')
# BANNED (prompt_idx=59, type=slop_phrase, phrase='chronometer')
# BANNED (prompt_idx=72, type=slop_phrase, phrase='stared')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='dampness')
# BANNED (prompt_idx=38, type=slop_phrase, phrase='flickered')
# BANNED (prompt_idx=43, type=slop_phrase, phrase='name is silas vance')
# BANNED (prompt_idx=75, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=48, type=ngram, ngram='sheer overwhelming')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=32, type=ngram, ngram='life meticulously')
# BANNED (prompt_idx=55, type=slop_phrase, phrase='leaden')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='vibrated')
# BANNED (prompt_idx=5, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='crackled')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=10, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=7, type=slop_phrase, phrase='meticulous')
# BANNED (prompt_idx=41, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=20, type=slop_phrase, phrase='untamed')
# BANNED (prompt_idx=4, type=ngram, ngram='woman named')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='chronos')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='dampness')
# BANNED (prompt_idx=50, type=slop_phrase, phrase='meticulousness')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='murmur')
# BANNED (prompt_idx=37, type=slop_phrase, phrase='xylos')
# BANNED (prompt_idx=47, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=8, type=ngram, ngram='three weeks')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='mournful')
# BANNED (prompt_idx=1, type=slop_phrase, phrase='whispered')
# BANNED (prompt_idx=11, type=ngram, ngram='slow agonizing')
# BANNED (prompt_idx=19, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='slicking')
# BANNED (prompt_idx=31, type=ngram, ngram='particularly unpleasant')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='anything remotely resembling')
# BANNED (prompt_idx=34, type=slop_phrase, phrase='subtly')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='mirrored')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=45, type=slop_phrase, phrase='felt like an eternity')
# BANNED (prompt_idx=67, type=slop_phrase, phrase='sickly')
# BANNED (prompt_idx=73, type=ngram, ngram='slow agonizing')
# BANNED (prompt_idx=54, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=70, type=slop_phrase, phrase='souffl')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=18, type=slop_phrase, phrase='obsessively')
# BANNED (prompt_idx=15, type=ngram, ngram='metallic tang')
# BANNED (prompt_idx=69, type=ngram, ngram='temporal displacement')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=40, type=ngram, ngram='slow agonizing')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='stared')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='mirroring')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='sickly')
# BANNED (prompt_idx=35, type=ngram, ngram='stench burnt flesh')
# BANNED (prompt_idx=57, type=slop_phrase, phrase='dampness')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='viscous')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='color of bruised plums')
# BANNED (prompt_idx=36, type=ngram, ngram='seemed vibrate')
# BANNED (prompt_idx=0, type=slop_phrase, phrase='crumbling')
# BANNED (prompt_idx=71, type=ngram, ngram='woman named')
# BANNED (prompt_idx=74, type=ngram, ngram='thick scent')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=55, type=slop_phrase, phrase='lukewarm')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=20, type=slop_phrase, phrase='windswept')
# BANNED (prompt_idx=48, type=slop_phrase, phrase='disconcerting')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='damp')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='muttered')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='perpetually')
# BANNED (prompt_idx=5, type=ngram, ngram='dull ache')
# BANNED (prompt_idx=10, type=ngram, ngram='slow agonizing')
# BANNED (prompt_idx=7, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=17, type=slop_phrase, phrase='fidgeting')
# BANNED (prompt_idx=12, type=slop_phrase, phrase='drizzle')
# BANNED (prompt_idx=78, type=ngram, ngram='metallic tang')
# BANNED (prompt_idx=79, type=ngram, ngram='seemed absorb')
# BANNED (prompt_idx=31, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=39, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=15, type=ngram, ngram='exactly like')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='slicked')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='mournful')
# BANNED (prompt_idx=50, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=56, type=ngram, ngram='hung thick')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='sputtered')
# BANNED (prompt_idx=40, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='laced')
# BANNED (prompt_idx=34, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=11, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=42, type=ngram, ngram='slow deliberate')
# BANNED (prompt_idx=54, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=67, type=slop_phrase, phrase='unwavering')
# BANNED (prompt_idx=70, type=ngram, ngram='quite reach')
# BANNED (prompt_idx=23, type=ngram, ngram='rise fall')
# BANNED (prompt_idx=32, type=slop_phrase, phrase='unremarkable')
# BANNED (prompt_idx=59, type=ngram, ngram='temporal displacement')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='lyra')
# BANNED (prompt_idx=72, type=slop_phrase, phrase='stared')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='ten years since')
# BANNED (prompt_idx=13, type=slop_phrase, phrase='laced')
# BANNED (prompt_idx=75, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=29, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=8, type=slop_phrase, phrase='elias')
# BANNED (prompt_idx=22, type=slop_phrase, phrase='blinked')
# BANNED (prompt_idx=9, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=47, type=slop_phrase, phrase='subtly')
# BANNED (prompt_idx=37, type=slop_phrase, phrase='xylos')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='meticulous')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='pestilence')
# BANNED (prompt_idx=46, type=ngram, ngram='name silas')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='clinking')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='dampness')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=41, type=slop_phrase, phrase='pulsed')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=16, type=ngram, ngram='seemed vibrate')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='air hung thick')
# BANNED (prompt_idx=57, type=slop_phrase, phrase='blurring')
# BANNED (prompt_idx=38, type=slop_phrase, phrase='shimmer')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='flickering')
# BANNED (prompt_idx=48, type=ngram, ngram='existential dread')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='disconcerting')
# BANNED (prompt_idx=55, type=slop_phrase, phrase='lukewarm')
# BANNED (prompt_idx=74, type=ngram, ngram='thick scent')
# BANNED (prompt_idx=20, type=slop_phrase, phrase='untamed')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='whispered')
# BANNED (prompt_idx=23, type=ngram, ngram='rise fall')
# BANNED (prompt_idx=71, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=31, type=ngram, ngram='small almost')
# BANNED (prompt_idx=0, type=slop_phrase, phrase='spent the last six')
# BANNED (prompt_idx=12, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='cobblestones')
# BANNED (prompt_idx=7, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=60, type=slop_phrase, phrase='damp')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=41, type=slop_phrase, phrase='hummed')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='meticulous')
# BANNED (prompt_idx=1, type=ngram, ngram='name silas')
# BANNED (prompt_idx=39, type=slop_phrase, phrase='predictably')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='man who looked like')
# BANNED (prompt_idx=35, type=slop_phrase, phrase='clung')
# BANNED (prompt_idx=54, type=slop_phrase, phrase='stubbornly')
# BANNED (prompt_idx=45, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=75, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='howled')
# BANNED (prompt_idx=70, type=ngram, ngram='something felt')
# BANNED (prompt_idx=33, type=slop_phrase, phrase='curdle')
# BANNED (prompt_idx=50, type=ngram, ngram='particularly unpleasant')
# BANNED (prompt_idx=37, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=18, type=ngram, ngram='life life')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='blinked')
# BANNED (prompt_idx=22, type=slop_phrase, phrase='disconcerting')
# BANNED (prompt_idx=49, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='lukewarm')
# BANNED (prompt_idx=27, type=slop_phrase, phrase='predictably')
# BANNED (prompt_idx=28, type=slop_phrase, phrase='holographic')
# BANNED (prompt_idx=5, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='rhythmic')
# BANNED (prompt_idx=76, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=36, type=ngram, ngram='spent last')
# BANNED (prompt_idx=30, type=slop_phrase, phrase='man whose face')
# BANNED (prompt_idx=10, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=4, type=ngram, ngram='woman named')
# BANNED (prompt_idx=67, type=slop_phrase, phrase='man whose face')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=9, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=46, type=slop_phrase, phrase='crumbling')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='chronos')
# BANNED (prompt_idx=69, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=15, type=slop_phrase, phrase='curdle')
# BANNED (prompt_idx=47, type=ngram, ngram='repeating patterns')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='mournful')
# BANNED (prompt_idx=13, type=ngram, ngram='voice flat')
# BANNED (prompt_idx=43, type=slop_phrase, phrase='clutching')
# BANNED (prompt_idx=57, type=slop_phrase, phrase='blurring')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='ten years since')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='impeccably')
# BANNED (prompt_idx=11, type=slop_phrase, phrase='predictably')
# BANNED (prompt_idx=24, type=ngram, ngram='rain hammered')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='drizzle that clung to everything')
# BANNED (prompt_idx=6, type=slop_phrase, phrase='bewildered')
# BANNED (prompt_idx=58, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=32, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='simmering')
# BANNED (prompt_idx=19, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=38, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=63, type=ngram, ngram='name silas')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='melancholic')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='pestilence')
# BANNED (prompt_idx=48, type=ngram, ngram='temporal displacement')
# BANNED (prompt_idx=55, type=slop_phrase, phrase='flickering')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='rumble')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='scent')
# BANNED (prompt_idx=71, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='clinging')
# BANNED (prompt_idx=46, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='beige')
# BANNED (prompt_idx=4, type=ngram, ngram='quiet insistent')
# BANNED (prompt_idx=65, type=slop_phrase, phrase='elias')
# BANNED (prompt_idx=77, type=slop_phrase, phrase='dampness')
# BANNED (prompt_idx=69, type=slop_phrase, phrase='kaleidoscope')
# BANNED (prompt_idx=19, type=slop_phrase, phrase='unsettling')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=26, type=ngram, ngram='thirty years')
# BANNED (prompt_idx=18, type=slop_phrase, phrase='devoid')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=28, type=slop_phrase, phrase='unsettling')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='pestilence')
# BANNED (prompt_idx=51, type=slop_phrase, phrase='lukewarm')
# BANNED (prompt_idx=14, type=slop_phrase, phrase='unremarkable')
# ...
# BANNED (prompt_idx=41, type=slop_phrase, phrase='tremor')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='fleeting')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='unease')
# BANNED (prompt_idx=2, type=slop_phrase, phrase='unreadable')
# BANNED (prompt_idx=66, type=ngram, ngram='spent entire life')
# BANNED (prompt_idx=73, type=ngram, ngram='stark contrast')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=21, type=ngram, ngram='simply stared')
# BANNED (prompt_idx=14, type=ngram, ngram='started small')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='unlived')
# BANNED (prompt_idx=56, type=ngram, ngram='carefully constructed')
# BANNED (prompt_idx=53, type=slop_phrase, phrase='mumbled')
# BANNED (prompt_idx=4, type=ngram, ngram='faint almost')
# BANNED (prompt_idx=31, type=slop_phrase, phrase='lyra')
# BANNED (prompt_idx=74, type=ngram, ngram='carefully constructed')
# BANNED (prompt_idx=36, type=ngram, ngram='said voice')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='something vaguely metallic')
# BANNED (prompt_idx=41, type=ngram, ngram='faint almost')
# BANNED (prompt_idx=64, type=ngram, ngram='said voice')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='malakor')
# BANNED (prompt_idx=43, type=slop_phrase, phrase='devoid')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='crumbling')
# BANNED (prompt_idx=44, type=ngram, ngram='words carefully')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='laced')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='roughened')
# BANNED (prompt_idx=62, type=slop_phrase, phrase='stared')
# BANNED (prompt_idx=12, type=slop_phrase, phrase='low, resonant hum')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='unease')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='impassive')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=79, type=slop_phrase, phrase='relentless march of time')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='simmering')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='stared')
# BANNED (prompt_idx=16, type=ngram, ngram='feeling something')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='relentless')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=53, type=ngram, ngram='spent life')
# BANNED (prompt_idx=64, type=slop_phrase, phrase='lingering')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='voice barely a whisper')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='unease')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='flickering')
# BANNED (prompt_idx=55, type=ngram, ngram='said voice')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='prickling')
# BANNED (prompt_idx=61, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='rasp')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='thorne')
# BANNED (prompt_idx=63, type=slop_phrase, phrase='whispered')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='lyra')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='calloused')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='devoid')
# BANNED (prompt_idx=66, type=ngram, ngram='said voice')
# BANNED (prompt_idx=78, type=ngram, ngram='carefully constructed')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='crumbling')
# BANNED (prompt_idx=16, type=ngram, ngram='like echoes something')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=56, type=ngram, ngram='living breathing')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='flickering')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='roughened')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='man whose face')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='insistent')
# BANNED (prompt_idx=66, type=ngram, ngram='voice laced')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=44, type=ngram, ngram='barely audible')
# BANNED (prompt_idx=63, type=ngram, ngram='strategically placed')
# BANNED (prompt_idx=36, type=ngram, ngram='voice laced')
# BANNED (prompt_idx=78, type=ngram, ngram='desperate need')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='unassuming')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='unsettlingly')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='meticulous')
# BANNED (prompt_idx=56, type=slop_phrase, phrase='dismissively')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='flickered')
# BANNED (prompt_idx=4, type=slop_phrase, phrase='suffocating')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=23, type=ngram, ngram='eyes held')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='gestured')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='fleeting')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='laced')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='bewildered')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='rasp')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='incinerating')
# BANNED (prompt_idx=74, type=slop_phrase, phrase='oakhaven')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='grizzled')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='holographic')
# BANNED (prompt_idx=25, type=slop_phrase, phrase='pulsed')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='unwavering')
# BANNED (prompt_idx=24, type=ngram, ngram='woman named')
# BANNED (prompt_idx=4, type=ngram, ngram='desperately trying')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='knelt')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='frantic')
# BANNED (prompt_idx=21, type=ngram, ngram='silent observer')
# BANNED (prompt_idx=44, type=slop_phrase, phrase='pulsed')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=73, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=52, type=ngram, ngram='desperate need')
# BANNED (prompt_idx=78, type=ngram, ngram='knuckles white')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='holographic')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='vance')
# BANNED (prompt_idx=24, type=ngram, ngram='woman named')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='unwavering')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='nudged')
# BANNED (prompt_idx=21, type=slop_phrase, phrase='predictably')
# BANNED (prompt_idx=25, type=ngram, ngram='spent life')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='stared')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='meticulous')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='holographic')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=16, type=ngram, ngram='asked voice')
# BANNED (prompt_idx=23, type=ngram, ngram='barely perceptible')
# BANNED (prompt_idx=63, type=ngram, ngram='desperate attempt')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='stammered')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='silas')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='meticulous')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='subtly')
# BANNED (prompt_idx=36, type=slop_phrase, phrase='unsettling')
# BANNED (prompt_idx=3, type=slop_phrase, phrase='vibrate')
# BANNED (prompt_idx=66, type=slop_phrase, phrase='mumbled')
# BANNED (prompt_idx=16, type=ngram, ngram='asked voice')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='sterile')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='croak')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='subtly')
# BANNED (prompt_idx=23, type=ngram, ngram='almost imperceptible')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='utterly')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='croak')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='bioluminescent')
# BANNED (prompt_idx=23, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='rasped')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='bewildered')
# BANNED (prompt_idx=16, type=ngram, ngram='demanded voice')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='croak')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='blinked')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='swirling')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='bioluminescent')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='rasped')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='grunted')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='bewildered')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='meticulously')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='shimmering')
# BANNED (prompt_idx=24, type=ngram, ngram='said voice')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='laced')
# BANNED (prompt_idx=78, type=slop_phrase, phrase='flicker')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='iridescent')
# BANNED (prompt_idx=24, type=slop_phrase, phrase='smelled')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='laced')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='perpetually')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='xylos')
# BANNED (prompt_idx=52, type=slop_phrase, phrase='unsettling')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='stammered')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='chirped')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='stuttered')
# BANNED (prompt_idx=16, type=ngram, ngram='replied voice')
# BANNED (prompt_idx=68, type=slop_phrase, phrase='stammered')
# BANNED (prompt_idx=16, type=slop_phrase, phrase='chirped')
# BANNED (prompt_idx=68, type=ngram, ngram='said voice')
# BANNED (prompt_idx=68, type=ngram, ngram='replied voice')
# Batch Generating: 100%|██████████| 80/80 [02:26<00:00,  1.83s/prompt, 338.2 tok/s]
# Finished processing 80 prompts in this run in 146.09s.
# Overall average throughput for this run: 338.21 tok/s.
# Results appended to results/iterative_antislop_experiment/run_20250510_090827/iter_1_creative_writing_generations.jsonl
# ✅  main.py finished — output saved to results/iterative_antislop_experiment/run_20250510_090827/iter_1_creative_writing_generations.jsonl
#
# --- Analyzing Outputs for iter_1_creative_writing_generations.jsonl ---
# INFO: Normalizing human 2-grams: Processed 200000 items. Resulted in 200000 unique normalized 2-gram keys. 0 original items were skipped or merged.
# INFO: Normalizing human 3-grams: Processed 200000 items. Resulted in 200000 unique normalized 3-gram keys. 0 original items were skipped or merged.
# N-gram analysis CSVs written to /home/sam/code/ai/antislop-api/results/iterative_antislop_experiment/run_20250510_090827/iter_1_analysis_results
# 🔎  over-rep word CSV → results/iterative_antislop_experiment/run_20250510_090827/iter_1_analysis_results/overrepresented_words.csv  (6521 rows)
# Updated banned n-grams list at results/iterative_antislop_experiment/run_20250510_090827/banned_ngrams.json. Total banned: 1281.
# Added 336 new unique n-grams to the list.
# MP substring extraction: 100%|██████████| 80/80 [00:00<00:00, 592.49it/s]
# 🚫  Slop-phrase ban list updated → results/iterative_antislop_experiment/run_20250510_090827/banned_slop_phrases.json   (now 853 entries; +289 new)
# 📁  DPO dataset written → results/iterative_antislop_experiment/run_20250510_090827/dpo_pairs_dataset.jsonl (80 prompt pairs)
#
# 📊  Final statistics written → /home/sam/code/ai/antislop-api/results/iterative_antislop_experiment/run_20250510_090827/final_iteration_statistics.csv
#  iteration  generated_text_count  generated_char_count      ttr      rttr  repetition_per_100k                                                                                         output_file
#          0                    80                215093 0.201941 35.801095           291.501815 results/iterative_antislop_experiment/run_20250510_090827/iter_0_creative_writing_generations.jsonl
#          1                    80                218794 0.209230 37.418773           209.786374 results/iterative_antislop_experiment/run_20250510_090827/iter_1_creative_writing_generations.jsonl
